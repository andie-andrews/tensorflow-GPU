# %% [markdown]
# # Lesson 29: PyTorch neural network demonstration part 1
# ## Notebook set-up
# ### Imports

# %%
# Third party imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim

# Set random seeds for reproducibility
torch.manual_seed(315)
np.random.seed(315)

# Check for GPU availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %% [markdown]
# ## 1. Load preprocessed data

# %%
data = pd.read_pickle('https://gperdrizet.github.io/FSA_devops/assets/data/unit4/preprocessed_housing_data.pkl')

training_df = data['training_df']
testing_df = data['testing_df']
features = data['features']
label = data['label']

print(f'Training samples: {len(training_df)}')
print(f'Testing samples: {len(testing_df)}')
print(f'Features: {features}')
print(f'Label: {label}')
# Out:
# Training samples: 15480
# Testing samples: 5160
# Features: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# Label: MedHouseVal

# %% [markdown]
# ## 2. PyTorch nn.Sequential model
#
# The `nn.Sequential` container is the simplest way to build a neural network in PyTorch. It allows you to create models layer-by-layer in a linear stack, similar to Keras Sequential API.

# %% [markdown]
# ### 2.1. Create PyTorch Tensors

# %%
X_train = torch.tensor(training_df[features].values, dtype=torch.float32).to(device)
y_train = torch.tensor(training_df[label].values, dtype=torch.float32).unsqueeze(1).to(device)

X_test = torch.tensor(testing_df[features].values, dtype=torch.float32).to(device)
y_test = torch.tensor(testing_df[label].values, dtype=torch.float32).unsqueeze(1).to(device)

print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
# Out:
# X_train shape: torch.Size([15480, 8])
# y_train shape: torch.Size([15480, 1])

# %% [markdown]
# ### 2.2 Build DNN model

# %%
sequential_model = nn.Sequential(
    nn.Linear(8, 32), # Similar to 'Dense' in TensorFlow
    nn.ReLU(),        # Activation function for previous layer
    nn.Dropout(0.2),
    nn.Linear(32, 64),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(64, 32),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(32, 1)
).to(device)

print(sequential_model)
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=32, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.2, inplace=False)
#   (3): Linear(in_features=32, out_features=64, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.2, inplace=False)
#   (6): Linear(in_features=64, out_features=32, bias=True)
#   (7): ReLU()
#   (8): Dropout(p=0.2, inplace=False)
#   (9): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(sequential_model.parameters(), lr=1e-2)

# %%
def train_model(
        model: nn.Sequential,
        X_train: torch.tensor,
        y_train: torch.tensor,
        criterion: nn.MSELoss,
        optimizer: optim.Adam,
        epochs: int = 100
):
    '''Training loop in PyTorch'''

    history = {'loss': []}

    for epoch in range(epochs):

        # Initialization
        model.train()
        optimizer.zero_grad()

        # Forward pass
        predictions = model(X_train)

        # Calculate loss
        loss = criterion(predictions, y_train)

        # Save loss in history
        history['loss'].append(loss.item())

        # Backwards pass
        loss.backward()

        # Update weights
        optimizer.step()

        print(f'Epoch: {epoch}, loss: {loss.item():.4f}')

    return history

# %% [markdown]
# ### 2.4. Train model

# %%
sequential_history = train_model(
    model = sequential_model,
    X_train = X_train,
    y_train = y_train,
    criterion = criterion,
    optimizer = optimizer 
)
# Out:
# Epoch: 0, loss: 0.9967
# Epoch: 1, loss: 0.9506
# Epoch: 2, loss: 0.8909
# Epoch: 3, loss: 0.8201
# Epoch: 4, loss: 0.7410
# Epoch: 5, loss: 0.6702
# Epoch: 6, loss: 0.6311
# Epoch: 7, loss: 0.6211
# Epoch: 8, loss: 0.5930
# Epoch: 9, loss: 0.5458
# Epoch: 10, loss: 0.5106
# Epoch: 11, loss: 0.4995
# Epoch: 12, loss: 0.4965
# Epoch: 13, loss: 0.4849
# Epoch: 14, loss: 0.4700
# Epoch: 15, loss: 0.4651
# Epoch: 16, loss: 0.4576
# Epoch: 17, loss: 0.4459
# Epoch: 18, loss: 0.4325
# Epoch: 19, loss: 0.4256
# Epoch: 20, loss: 0.4109
# Epoch: 21, loss: 0.4097
# Epoch: 22, loss: 0.4020
# Epoch: 23, loss: 0.4007
# Epoch: 24, loss: 0.4005
# Epoch: 25, loss: 0.3900
# Epoch: 26, loss: 0.3806
# Epoch: 27, loss: 0.3799
# Epoch: 28, loss: 0.3722
# Epoch: 29, loss: 0.3722
# Epoch: 30, loss: 0.3689
# Epoch: 31, loss: 0.3674
# Epoch: 32, loss: 0.3625
# Epoch: 33, loss: 0.3556
# Epoch: 34, loss: 0.3555
# Epoch: 35, loss: 0.3556
# Epoch: 36, loss: 0.3502
# Epoch: 37, loss: 0.3470
# Epoch: 38, loss: 0.3470
# Epoch: 39, loss: 0.3433
# Epoch: 40, loss: 0.3419
# Epoch: 41, loss: 0.3410
# Epoch: 42, loss: 0.3352
# Epoch: 43, loss: 0.3350
# Epoch: 44, loss: 0.3331
# Epoch: 45, loss: 0.3340
# Epoch: 46, loss: 0.3282
# Epoch: 47, loss: 0.3285
# Epoch: 48, loss: 0.3239
# Epoch: 49, loss: 0.3230
# Epoch: 50, loss: 0.3223
# Epoch: 51, loss: 0.3213
# Epoch: 52, loss: 0.3153
# Epoch: 53, loss: 0.3154
# Epoch: 54, loss: 0.3134
# Epoch: 55, loss: 0.3134
# Epoch: 56, loss: 0.3093
# Epoch: 57, loss: 0.3101
# Epoch: 58, loss: 0.3081
# Epoch: 59, loss: 0.3050
# Epoch: 60, loss: 0.3047
# Epoch: 61, loss: 0.3022
# Epoch: 62, loss: 0.3004
# Epoch: 63, loss: 0.3015
# Epoch: 64, loss: 0.2950
# Epoch: 65, loss: 0.2972
# Epoch: 66, loss: 0.2953
# Epoch: 67, loss: 0.2949
# Epoch: 68, loss: 0.2964
# Epoch: 69, loss: 0.2939
# Epoch: 70, loss: 0.2923
# Epoch: 71, loss: 0.2898
# Epoch: 72, loss: 0.2926
# Epoch: 73, loss: 0.2912
# Epoch: 74, loss: 0.2906
# Epoch: 75, loss: 0.2918
# Epoch: 76, loss: 0.2839
# Epoch: 77, loss: 0.2860
# Epoch: 78, loss: 0.2857
# Epoch: 79, loss: 0.2829
# Epoch: 80, loss: 0.2852
# Epoch: 81, loss: 0.2851
# Epoch: 82, loss: 0.2831
# Epoch: 83, loss: 0.2816
# Epoch: 84, loss: 0.2804
# Epoch: 85, loss: 0.2806
# Epoch: 86, loss: 0.2772
# Epoch: 87, loss: 0.2809
# Epoch: 88, loss: 0.2749
# Epoch: 89, loss: 0.2712
# Epoch: 90, loss: 0.2758
# Epoch: 91, loss: 0.2786
# Epoch: 92, loss: 0.2756
# Epoch: 93, loss: 0.2749
# Epoch: 94, loss: 0.2718
# Epoch: 95, loss: 0.2696
# Epoch: 96, loss: 0.2704
# Epoch: 97, loss: 0.2743
# Epoch: 98, loss: 0.2729
# Epoch: 99, loss: 0.2721

# %% [markdown]
# ### 2.5. Plot learning curves

# %%
plt.title('Learning curve')
plt.plot(sequential_history['loss'])
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# ## 3. PyTorch nn.Module class-based model
#
# The `nn.Module` class provides more flexibility than `nn.Sequential`. It allows you to create models via subclassing with custom forward methods, non-linear topology, shared layers, and multiple inputs or outputs, similar to the Keras Functional API.
